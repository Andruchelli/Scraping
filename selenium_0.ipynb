# %%
from selenium.webdriver import Chrome

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
browser = Chrome('/Users/andrey/Documents/GitHub/API-JSON/chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py:42, in DriverFinder.get_path(service, options)
#      41 try:
# ---> 42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/selenium_manager.py:74, in SeleniumManager.driver_location(self, options)
#      72 logger.debug("Applicable driver not found; attempting to install with Selenium Manager (Beta)")
# ---> 74 browser = options.capabilities["browserName"]
#      76 args = [str(self.get_binary()), "--browser", browser, "--output", "json"]
#
# AttributeError: 'str' object has no attribute 'capabilities'
#
# During handling of the above exception, another exception occurred:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 browser = Chrome('/Users/andrey/Documents/GitHub/API-JSON/chromedriver.exe')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 self.options = options if options else Options()
#      45 self.keep_alive = keep_alive
# ---> 47 self.service.path = DriverFinder.get_path(self.service, self.options)
#      49 super().__init__(
#      50     DesiredCapabilities.CHROME["browserName"],
#      51     "goog",
#    (...)
#      54     self.keep_alive,
#      55 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py:44, in DriverFinder.get_path(service, options)
#      42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
# ---> 44     raise NoSuchDriverException(f"Unable to obtain {service.path} using Selenium Manager; {err}")
#      46 if path is None or not Path(path).is_file():
#      47     raise NoSuchDriverException(f"Unable to locate or obtain {service.path}")
#
# NoSuchDriverException: Message: Unable to obtain chromedriver using Selenium Manager; 'str' object has no attribute 'capabilities'; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %%
conda install -c conda-forge selenium
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/andrey/opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     async_generator-1.10       |     pyhd3eb1b0_0          23 KB
#     conda-package-handling-2.1.0|   py39hecd8cb5_0         270 KB
#     exceptiongroup-1.0.4       |   py39hecd8cb5_0          29 KB
#     h11-0.12.0                 |     pyhd3eb1b0_0          47 KB
#     ldid-2.1.5                 |       hc58f1be_3          64 KB
#     outcome-1.1.0              |     pyhd3eb1b0_0          14 KB
#     pyjwt-2.4.0                |   py39hecd8cb5_0          35 KB
#     trio-0.22.0                |   py39hecd8cb5_0         531 KB
#     ------------------------------------------------------------
#                                            Total:        1014 KB
#
# The following packages will be REMOVED:
#
#   python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   conda-package-han~                   1.8.1-py39hca72f7f_0 --> 2.1.0-py39hecd8cb5_0 None
#   ldid                                     2.1.2-h2d21305_2 --> 2.1.5-hc58f1be_3 None
#   pyjwt                                2.1.0-py39hecd8cb5_0 --> 2.4.0-py39hecd8cb5_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   async_generator    conda-forge::async_generator-1.10-py_0 --> pkgs/main::async_generator-1.10-pyhd3eb1b0_0 None
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.~ --> pkgs/main/osx-64::exceptiongroup-1.0.4-py39hecd8cb5_0 None
#   h11                  conda-forge::h11-0.14.0-pyhd8ed1ab_0 --> pkgs/main::h11-0.12.0-pyhd3eb1b0_0 None
#   outcome            conda-forge::outcome-1.2.0-pyhd8ed1ab~ --> pkgs/main::outcome-1.1.0-pyhd3eb1b0_0 None
#   trio               conda-forge::trio-0.22.0-py39h6e9494a~ --> pkgs/main::trio-0.22.0-py39hecd8cb5_0 None
#
#
#
# Downloading and Extracting Packages
# h11-0.12.0           | 47 KB     | ##################################### | 100%
# outcome-1.1.0        | 14 KB     | ##################################### | 100%
# trio-0.22.0          | 531 KB    | ##################################### | 100%
# exceptiongroup-1.0.4 | 29 KB     | ##################################### | 100%
# pyjwt-2.4.0          | 35 KB     | ##################################### | 100%
# conda-package-handli | 270 KB    | ##################################### | 100%
# ldid-2.1.5           | 64 KB     | ##################################### | 100%
# async_generator-1.10 | 23 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium.webdriver import Chrome

# %%
browser = Chrome('/Users/andrey/Documents/GitHub/API-JSON/chromedriver')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py:42, in DriverFinder.get_path(service, options)
#      41 try:
# ---> 42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/selenium_manager.py:74, in SeleniumManager.driver_location(self, options)
#      72 logger.debug("Applicable driver not found; attempting to install with Selenium Manager (Beta)")
# ---> 74 browser = options.capabilities["browserName"]
#      76 args = [str(self.get_binary()), "--browser", browser, "--output", "json"]
#
# AttributeError: 'str' object has no attribute 'capabilities'
#
# During handling of the above exception, another exception occurred:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 browser = Chrome('Users/andrey/Documents/GitHub/API-JSON/chromedriver')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 self.options = options if options else Options()
#      45 self.keep_alive = keep_alive
# ---> 47 self.service.path = DriverFinder.get_path(self.service, self.options)
#      49 super().__init__(
#      50     DesiredCapabilities.CHROME["browserName"],
#      51     "goog",
#    (...)
#      54     self.keep_alive,
#      55 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py:44, in DriverFinder.get_path(service, options)
#      42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
# ---> 44     raise NoSuchDriverException(f"Unable to obtain {service.path} using Selenium Manager; {err}")
#      46 if path is None or not Path(path).is_file():
#      47     raise NoSuchDriverException(f"Unable to locate or obtain {service.path}")
#
# NoSuchDriverException: Message: Unable to obtain chromedriver using Selenium Manager; 'str' object has no attribute 'capabilities'; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %%
driver = webdriver.Chrome(service=service, options=chrome_options)
driver.get
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 browser = webdriver.Chrome(service=service, options=chrome_options)
#
# NameError: name 'webdriver' is not defined

# %%
! pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.9.0-py2.py3-none-any.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.2/277.2 kB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting Twisted>=18.9.0 (from scrapy)
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.9 MB/s eta 0:00:0000:0100:01
# Collecting cryptography>=3.4.6 (from scrapy)
#   Downloading cryptography-41.0.2-cp37-abi3-macosx_10_12_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 24.6 MB/s eta 0:00:0000:0100:01
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.1.0-py3-none-any.whl (11 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Collecting pyOpenSSL>=21.0.0 (from scrapy)
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 2.8 MB/s eta 0:00:00
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-23.1.0-py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-6.0-cp39-cp39-macosx_10_9_x86_64.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.3/202.3 kB 8.5 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from scrapy) (49.2.1)
# Requirement already satisfied: packaging in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from scrapy) (21.3)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-3.4.4-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 3.9 MB/s eta 0:00:00
# Collecting lxml>=4.3.0 (from scrapy)
#   Downloading lxml-4.9.3.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: cffi>=1.12 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from protego>=0.1.15->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (22.1.0)
# Requirement already satisfied: pyasn1 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Collecting constantly>=15.1 (from Twisted>=18.9.0->scrapy)
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting incremental>=21.3.0 (from Twisted>=18.9.0->scrapy)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0 (from Twisted>=18.9.0->scrapy)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=18.9.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from packaging->scrapy) (3.0.9)
# Requirement already satisfied: idna in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from tldextract->scrapy) (2.28.1)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Collecting filelock>=3.0.8 (from tldextract->scrapy)
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: pycparser in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrey/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [119 lines of output]
#       Building lxml version 4.9.3.
#       Building without Cython.
#       Building against libxml2 2.9.4 and libxslt 1.1.29
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.13-x86_64-3.9
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/_elementpath.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/sax.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/pyclasslookup.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/__init__.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/builder.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/doctestcompare.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/usedoctest.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/cssselect.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/ElementInclude.py -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/__init__.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/soupparser.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/defs.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/_setmixin.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/clean.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/_diffcommand.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/html5parser.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/__init__.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/formfill.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/builder.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/ElementSoup.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/_html5builder.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/usedoctest.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       copying src/lxml/html/diff.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/html
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron
#       copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron
#       copying src/lxml/etree.h -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/etree_api.h -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/lxml.etree.h -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/lxml.etree_api.h -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/objectify.pyx -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/etree.pyx -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/public-api.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xmlid.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/cleanup.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xslt.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xpath.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/debug.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/serializer.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/classlookup.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/saxparser.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/objectpath.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/relaxng.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xinclude.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/iterparse.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/parser.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/dtd.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/apihelpers.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xmlerror.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/readonlytree.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/extensions.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xmlschema.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/schematron.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/docloader.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/nsclasses.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/parsertarget.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/xsltext.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/proxy.pxi -> build/lib.macosx-10.13-x86_64-3.9/lxml
#       copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/c14n.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/__init__.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/schematron.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/tree.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/uri.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/xpath.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/xslt.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/config.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/lxml-version.h -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       copying src/lxml/includes/etree_defs.h -> build/lib.macosx-10.13-x86_64-3.9/lxml/includes
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/rng
#       copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/rng
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl
#       creating build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-10.13-x86_64-3.9/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       running build_ext
#       building 'lxml.etree' extension
#       creating build/temp.macosx-10.13-x86_64-3.9
#       creating build/temp.macosx-10.13-x86_64-3.9/src
#       creating build/temp.macosx-10.13-x86_64-3.9/src/lxml
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -DCYTHON_CLINE_IN_TRACEBACK=0 -I/usr/include/libxml2 -Isrc -Isrc/lxml/includes -I/Users/andrey/.pyenv/versions/3.9.0/include/python3.9 -c src/lxml/etree.c -o build/temp.macosx-10.13-x86_64-3.9/src/lxml/etree.o -w -flat_namespace
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       Compile failed: command '/usr/bin/clang' failed with exit code 1
#       creating var
#       creating var/folders
#       creating var/folders/hy
#       creating var/folders/hy/pfmkjt294bl40vdb0nfc_y4c0000gn
#       creating var/folders/hy/pfmkjt294bl40vdb0nfc_y4c0000gn/T
#       cc -I/usr/include/libxml2 -I/usr/include/libxml2 -c /var/folders/hy/pfmkjt294bl40vdb0nfc_y4c0000gn/T/xmlXPathInitdorao34d.c -o var/folders/hy/pfmkjt294bl40vdb0nfc_y4c0000gn/T/xmlXPathInitdorao34d.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       *********************************************************************************
#       Could not find function xmlCheckVersion in library libxml2. Is libxml2 installed?
#       Perhaps try: xcode-select --install
#       *********************************************************************************
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for lxml
#   Running setup.py clean for lxml
# Failed to build lxml
# ERROR: Could not build wheels for lxml, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip
